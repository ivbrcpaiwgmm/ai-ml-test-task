# %%
from main import DataVisualizer


dvl = DataVisualizer('deviation.json')
plot_1_path = dvl.corners_prediction_scatter()
plot_2_path = dvl.mean_deviation_histogram()
plot_3_path = dvl.mean_floor_vs_ceiling_boxplot()
